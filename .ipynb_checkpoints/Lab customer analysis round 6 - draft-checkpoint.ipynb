# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error

# %%
df1 = pd.read_csv('Lab_customer_analysis_round_2.csv')

# %%
df1.columns
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'response', 'coverage',
#        'education', 'effective_to_date', 'employment_status', 'gender',
#        'income', 'location_code', 'marital_status', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'policy_type',
#        'policy', 'renew_offer_type', 'sales_channel', 'total_claim_amount',
#        'vehicle_class', 'vehicle_size'],
#       dtype='object')

# %%
df1 = df1.drop(columns = ['Unnamed: 0', 'effective_to_month'])
# I dropped 'unnamed' bc it was created automatically from the csv file I exported before
df1
# Out:
#      customer       state  customer_lifetime_value response  coverage  \
# 0     PB63095  Washington              5568.947534      Yes  Extended
# 1     XJ97760  California              4739.861234       No     Basic
# 2     RA27021      Nevada             27564.739510       No  Extended
# 3     OG30514      Nevada             20018.204590       No     Basic
# 4     GJ44951  Washington              4698.759935       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  XA55917  California              8533.832013       No     Basic
# 9130  KM65135      Oregon              4763.327142       No     Basic
# 9131  EB61889  California              9486.037005       No  Extended
# 9132  SB83749  California              4717.628730       No     Basic
# 9133  AU46443      Nevada              7517.083811       No     Basic
#
#                  education effective_to_date employment_status gender  income  \
# ...

# %%
#Check the data types of the columns
#df1.dtypes

# %%
# Get the numeric data into dataframe called numerical [...]

# %%
#numeric_types = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
X_num = df1.select_dtypes(include=np.number)
X_num
# Out:
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                 5568.947534       0                    79
# 1                 4739.861234   35039                    61
# 2                27564.739510   26410                    91
# 3                20018.204590   65900                    62
# 4                 4698.759935       0                    67
# ...                       ...     ...                   ...
# 9129              8533.832013   26049                   113
# 9130              4763.327142   14957                    66
# 9131              9486.037005   25322                   126
# 9132              4717.628730   20355                    61
# 9133              7517.083811       0                   102
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                          21                             53
# 1                           7                             87
# ...

# %%
# [...] and categorical columns in a dataframe called categoricals
X_cat = df1.select_dtypes(include=np.object)
X_cat
# Out:
#      customer       state response  coverage             education  \
# 0     PB63095  Washington      Yes  Extended  High School or Below
# 1     XJ97760  California       No     Basic                Master
# 2     RA27021      Nevada       No  Extended              Bachelor
# 3     OG30514      Nevada       No     Basic              Bachelor
# 4     GJ44951  Washington       No     Basic              Bachelor
# ...       ...         ...      ...       ...                   ...
# 9129  XA55917  California       No     Basic               College
# 9130  KM65135      Oregon       No     Basic               College
# 9131  EB61889  California       No  Extended  High School or Below
# 9132  SB83749  California       No     Basic  High School or Below
# 9133  AU46443      Nevada       No     Basic              Bachelor
#
#      effective_to_date employment_status gender location_code marital_status  \
# 0           2011-01-01        Unemployed      M      Suburban         Single
# ...

# %%
#categoricals.columns

# %%
# X_y split (eventually after cleaning)
#watch out when is the best time for me to do the splits
y = df1['total_claim_amount'] #so here we select a column which we define as output
X = df1.drop(['total_claim_amount'], axis=1) # here we assign the input with the dataframe content except the output
df1 = X.drop(['customer'], axis=1)

# %%
X.head(3)
# Out:
#   customer       state  customer_lifetime_value response  coverage  \
# 0  PB63095  Washington              5568.947534      Yes  Extended
# 1  XJ97760  California              4739.861234       No     Basic
# 2  RA27021      Nevada             27564.739510       No  Extended
#
#               education effective_to_date employment_status gender  income  \
# 0  High School or Below        2011-01-01        Unemployed      M       0
# 1                Master        2011-01-01          Employed      M   35039
# 2              Bachelor        2011-01-01          Disabled      F   26410
#
#    ... months_since_last_claim months_since_policy_inception  \
# 0  ...                      21                            53
# 1  ...                       7                            87
# 2  ...                      17                            90
#
#    number_of_open_complaints  number_of_policies     policy_type  \
# 0                          1                   7   Personal Auto
# ...

# %%
# X_y split (eventually after cleaning)
#watch out when is the best time for me to do the splits
#y = df1['total_claim_amount'] #so here we select a column which we define as output
#X = df1.drop(['total_claim_amount'], axis=1) # here we assign the input with the dataframe content except the output

# %%
#X_num = X.select_dtypes(include = np.number)
#X_cat = X.select_dtypes(include = np.object)

#get_dummies turns it into a boolean
#categoricals = pd.get_dummies(X_cat, drop_first=True)
#categoricals

# %%
#Normalize (numerical):

# %%
# (Just drop the customer)

# %%
#Concatenate: 
X = np.concatenate([X_num, encoded], axis=1) #side by side
#le truc puissant c'est qu'on peut inclure
# des valeurs numériques et catégoriques

# %%
encoded.shape

# %%
# Show a plot of the total number of responses:
sns.countplot(x='response', data=df1)
plt.show()

# %%
# Show a plot of the response rate by the sales channel:
sns.countplot(x='response', hue='sales_channel', data=df1)
plt.show()

# %%
#df2 = df1.copy()

# %%
# Show a plot of the response rate by the total claim amount:
sns.barplot(x='response', y='total_claim_amount', data=df1)
plt.show()
